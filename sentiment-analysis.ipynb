# %%
import pandas as pd

books=pd.read_csv('books_with_categories.csv')

# %%
from transformers import pipeline
from huggingface_hub import login

# Log in using your Hugging Face token
login("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")

# Load the model
pipe = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", top_k=None, device="cpu")
# Out:
# Device set to use cpu

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
pipe(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.6548418998718262},
#   {'label': 'neutral', 'score': 0.16985182464122772},
#   {'label': 'sadness', 'score': 0.11640854179859161},
#   {'label': 'surprise', 'score': 0.020700592547655106},
#   {'label': 'disgust', 'score': 0.01910073682665825},
#   {'label': 'joy', 'score': 0.015161239542067051},
#   {'label': 'anger', 'score': 0.00393515033647418}]]

# %%
pipe(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296027541160583},
#   {'label': 'neutral', 'score': 0.14038576185703278},
#   {'label': 'fear', 'score': 0.06816209107637405},
#   {'label': 'joy', 'score': 0.04794240742921829},
#   {'label': 'anger', 'score': 0.00915635284036398},
#   {'label': 'disgust', 'score': 0.0026284719351679087},
#   {'label': 'sadness', 'score': 0.0021221607457846403}],
#  [{'label': 'neutral', 'score': 0.449370414018631},
#   {'label': 'disgust', 'score': 0.27359241247177124},
#   {'label': 'joy', 'score': 0.10908260941505432},
#   {'label': 'sadness', 'score': 0.09362703561782837},
#   {'label': 'anger', 'score': 0.040478307753801346},
#   {'label': 'surprise', 'score': 0.02697017230093479},
#   {'label': 'fear', 'score': 0.006879065651446581}],
#  [{'label': 'neutral', 'score': 0.6462168097496033},
#   {'label': 'sadness', 'score': 0.2427326887845993},
#   {'label': 'disgust', 'score': 0.04342268034815788},
#   {'label': 'surprise', 'score': 0.028300466015934944},
#   {'label': 'joy', 'score': 0.014211482368409634},
#   {'label': 'fear', 'score': 0.014084089547395706},
#   {'label': 'anger', 'score': 0.011031883768737316}],
#  [{'label': 'fear', 'score': 0.928168535232544},
#   {'label': 'anger', 'score': 0.0321907103061676},
#   {'label': 'neutral', 'score': 0.012808633036911488},
#   {'label': 'sadness', 'score': 0.00875683594495058},
#   {'label': 'surprise', 'score': 0.008597894571721554},
#   {'label': 'disgust', 'score': 0.008431794121861458},
#   {'label': 'joy', 'score': 0.0010455806041136384}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104170888662338},
#   {'label': 'disgust', 'score': 0.006480592768639326},
#   {'label': 'fear', 'score': 0.005393994972109795},
#   {'label': 'surprise', 'score': 0.0022869433742016554},
#   {'label': 'anger', 'score': 0.0018428886542096734},
#   {'label': 'joy', 'score': 0.001733880490064621}],
#  [{'label': 'joy', 'score': 0.9327982664108276},
#   {'label': 'disgust', 'score': 0.03771686181426048},
#   {'label': 'neutral', 'score': 0.015891842544078827},
#   {'label': 'sadness', 'score': 0.006444473285228014},
#   {'label': 'anger', 'score': 0.005024951882660389},
#   {'label': 'surprise', 'score': 0.0015812074998393655},
#   {'label': 'fear', 'score': 0.0005423047696240246}],
#  [{'label': 'joy', 'score': 0.6528704166412354},
#   {'label': 'neutral', 'score': 0.254274845123291},
#   {'label': 'surprise', 'score': 0.06808319687843323},
#   {'label': 'sadness', 'score': 0.009908993728458881},
#   {'label': 'disgust', 'score': 0.00651219068095088},
#   {'label': 'anger', 'score': 0.004821313079446554},
#   {'label': 'fear', 'score': 0.003529015462845564}],
#  [{'label': 'neutral', 'score': 0.5494767427444458},
#   {'label': 'sadness', 'score': 0.11169015616178513},
#   {'label': 'disgust', 'score': 0.10400672256946564},
#   {'label': 'surprise', 'score': 0.07876548916101456},
#   {'label': 'anger', 'score': 0.06413363665342331},
#   {'label': 'fear', 'score': 0.05136279761791229},
#   {'label': 'joy', 'score': 0.040564414113759995}]]

# %%
sentences= books["description"][0].split(".")
predictions= pipe(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296027541160583},
#  {'label': 'neutral', 'score': 0.14038576185703278},
#  {'label': 'fear', 'score': 0.06816209107637405},
#  {'label': 'joy', 'score': 0.04794240742921829},
#  {'label': 'anger', 'score': 0.00915635284036398},
#  {'label': 'disgust', 'score': 0.0026284719351679087},
#  {'label': 'sadness', 'score': 0.0021221607457846403}]

# %%
sorted(predictions[0],key =lambda x:x["label"])
# Out:
# [{'label': 'anger', 'score': 0.00915635284036398},
#  {'label': 'disgust', 'score': 0.0026284719351679087},
#  {'label': 'fear', 'score': 0.06816209107637405},
#  {'label': 'joy', 'score': 0.04794240742921829},
#  {'label': 'neutral', 'score': 0.14038576185703278},
#  {'label': 'sadness', 'score': 0.0021221607457846403},
#  {'label': 'surprise', 'score': 0.7296027541160583}]

# %%
import numpy as np

emotion_labels=["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn=[]
emotion_scores={label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores={label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x:x["label"])
        for index,label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
        return {label:np.max(scores) for label,scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences=books["description"][i].split(".")
    predictions=pipe(sentences)
    max_scores=calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [0.00915635284036398,
#   0.005966844502836466,
#   0.005966844502836466,
#   0.005966844502836466,
#   0.04130087420344353,
#   0.016036177054047585,
#   0.016036177054047585,
#   0.016036177054047585,
#   0.013624361716210842,
#   0.013624361716210842],
#  'disgust': [0.0026284719351679087,
#   0.0028870662208646536,
#   0.0028870662208646536,
#   0.0028870662208646536,
#   0.024568378925323486,
#   0.06069502979516983,
#   0.06069502979516983,
#   0.06069502979516983,
#   0.12224263697862625,
#   0.12224263697862625],
#  'fear': [0.06816209107637405,
#   0.0038098806980997324,
#   0.0038098806980997324,
#   0.0038098806980997324,
#   0.10406126081943512,
#   0.0016916330205276608,
#   0.0016916330205276608,
#   0.0016916330205276608,
#   0.0950433686375618,
#   0.0950433686375618],
#  'joy': [0.04794240742921829,
#   0.7044215202331543,
#   0.7044215202331543,
#   0.7044215202331543,
#   0.7672374844551086,
#   0.16175702214241028,
#   0.16175702214241028,
#   0.16175702214241028,
#   0.008335662074387074,
#   0.008335662074387074],
#  'sadness': [0.14038576185703278,
#   0.21776005625724792,
#   0.21776005625724792,
#   0.21776005625724792,
#   0.04217596352100372,
#   0.732685387134552,
#   0.732685387134552,
#   0.732685387134552,
#   0.27261361479759216,
#   0.27261361479759216],
#  'surprise': [0.0021221607457846403,
#   0.004508520942181349,
#   0.004508520942181349,
#   0.004508520942181349,
#   0.01085986103862524,
#   0.02098814956843853,
#   0.02098814956843853,
#   0.02098814956843853,
#   0.47588053345680237,
#   0.47588053345680237],
#  'neutral': [0.7296027541160583,
#   0.060646045953035355,
#   0.060646045953035355,
#   0.060646045953035355,
#   0.009796065278351307,
#   0.006146552041172981,
#   0.006146552041172981,
#   0.006146552041172981,
#   0.012259824201464653,
#   0.012259824201464653]}

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = pipe(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 6029/6029 [28:34<00:00,  3.52it/s]

# %%
emotions_df=pd.DataFrame(emotion_scores)
emotions_df["isbn13"]=isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.009156  0.002628  0.068162  0.047942  0.140386  0.002122  0.729603
# 1     0.005967  0.002887  0.003810  0.704422  0.217760  0.004509  0.060646
# 2     0.005967  0.002887  0.003810  0.704422  0.217760  0.004509  0.060646
# 3     0.005967  0.002887  0.003810  0.704422  0.217760  0.004509  0.060646
# 4     0.041301  0.024568  0.104061  0.767237  0.042176  0.010860  0.009796
# ...        ...       ...       ...       ...       ...       ...       ...
# 6024  0.025156  0.001939  0.094667  0.002254  0.010511  0.857255  0.008218
# 6025  0.005602  0.003775  0.018216  0.400263  0.338892  0.005487  0.227765
# 6026  0.008463  0.009147  0.013295  0.620453  0.329753  0.010788  0.008101
# 6027  0.005475  0.034545  0.003970  0.258353  0.648011  0.017372  0.032275
# 6028  0.002837  0.003137  0.001166  0.958549  0.028252  0.002916  0.003142
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780002261982
# 3     9780002261982
# 4     9780006178736
# ...             ...
# 6024  9788172235222
# 6025  9788173031014
# 6026  9788179921623
# 6027  9788185300535
# 6028  9789027712059
#
# [6029 rows x 8 columns]

# %%
books=pd.merge(books,emotions_df,on="isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780002261982  0002261987
# 3     9780002261982  0002261987
# 4     9780002261982  0002261987
# ...             ...         ...
# 7704  9788172235222  8172235224
# 7705  9788173031014  8173031010
# 7706  9788179921623  817992162X
# 7707  9788185300535  8185300534
# 7708  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          Spider's Web
# 3                                          Spider's Web
# 4                                          Spider's Web
# ...                                                 ...
# 7704                                  Mistaken Identity
# 7705                                Journey to the East
# 7706  The Monk Who Sold His Ferrari: A Fable About F...
# 7707                                          I Am that
# 7708                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                  Charles Osborne;Agatha Christie
# 3                  Charles Osborne;Agatha Christie
# 4                  Charles Osborne;Agatha Christie
# ...                                            ...
# 7704                              Nayantara Sahgal
# 7705                                 Hermann Hesse
# 7706                                  Robin Sharma
# 7707  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 7708                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2     Detective and mystery stories
# 3     Detective and mystery stories
# 4     Detective and mystery stories
# ...                             ...
# 7704        Indic fiction (English)
# 7705              Adventure stories
# 7706               Health & Fitness
# 7707                     Philosophy
# 7708                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=gA5GP...
# 3     http://books.google.com/books/content?id=gA5GP...
# 4     http://books.google.com/books/content?id=gA5GP...
# ...                                                 ...
# 7704  http://books.google.com/books/content?id=q-tKP...
# 7705  http://books.google.com/books/content?id=rq6JP...
# 7706  http://books.google.com/books/content?id=c_7mf...
# 7707  http://books.google.com/books/content?id=Fv_JP...
# 7708  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 3     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 4     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# ...                                                 ...             ...
# 7704  On A Train Journey Home To North India After L...          2003.0
# 7705  This book tells the tale of a man who goes on ...          2002.0
# 7706  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 7707  This collection of the timeless teachings of o...          1999.0
# 7708  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.83      241.0  ...
# 3               3.83      241.0  ...
# 4               3.83      241.0  ...
# ...              ...        ...  ...
# 7704            2.93      324.0  ...
# 7705            3.70      175.0  ...
# 7706            3.82      198.0  ...
# 7707            4.51      531.0  ...
# 7708            0.00      210.0  ...
#
#                                      title and subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                 Spider's Web: A Novel
# 3                                 Spider's Web: A Novel
# 4                                 Spider's Web: A Novel
# ...                                                 ...
# 7704                                  Mistaken Identity
# 7705                                Journey to the East
# 7706  The Monk Who Sold His Ferrari: A Fable About F...
# 7707     I Am that: Talks with Sri Nisargadatta Maharaj
# 7708                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 3     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 4     9780002261982 A new 'Christie for Christmas' -...           Fiction
# ...                                                 ...               ...
# 7704  9788172235222 On A Train Journey Home To North...           Fiction
# 7705  9788173031014 This book tells the tale of a ma...        Nonfiction
# 7706  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 7707  9788185300535 This collection of the timeless ...        Nonfiction
# 7708  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   sadness  surprise   neutral
# 0     0.009156  0.002628  0.068162  0.047942  0.140386  0.002122  0.729603
# 1     0.005967  0.002887  0.003810  0.704422  0.217760  0.004509  0.060646
# 2     0.005967  0.002887  0.003810  0.704422  0.217760  0.004509  0.060646
# 3     0.005967  0.002887  0.003810  0.704422  0.217760  0.004509  0.060646
# 4     0.005967  0.002887  0.003810  0.704422  0.217760  0.004509  0.060646
# ...        ...       ...       ...       ...       ...       ...       ...
# 7704  0.025156  0.001939  0.094667  0.002254  0.010511  0.857255  0.008218
# 7705  0.005602  0.003775  0.018216  0.400263  0.338892  0.005487  0.227765
# 7706  0.008463  0.009147  0.013295  0.620453  0.329753  0.010788  0.008101
# 7707  0.005475  0.034545  0.003970  0.258353  0.648011  0.017372  0.032275
# 7708  0.002837  0.003137  0.001166  0.958549  0.028252  0.002916  0.003142
#
# [7709 rows x 21 columns]

# %%
books.to_csv("books_with_emotions.csv",index=False)
